# %% [markdown]
# # Breaking Down the Data - Why First Count Position Matters More than Anything in Irish Elections

# %%
import pandas as pd
import json
import pickle

# %%
with open('data.pkl', 'rb') as f: data = pickle.load(f)

# %% [markdown]
# ## Nomenclature
#
# We need to coin some nomemclature, so that we're always sure what we're talking about. There are two terms I'd like to use throughout - `inside` and `outside`.
#
# ### Inside
# If a candidate is within the first $n$ positions after the first count in a consituency with $n$ seats, she shall be designated `inside`. That is, all candidates in the first three positions in a three-seat consituency on the first count, the first four positions in a four-seat constituency on the first count, or the first five positions in a five-seat constituency on the first count are designated `inside`.
#
# ### Outside
# All candidates who are not `inside` are `outside`.

# %%
def insideOutside(someDf):
    holder = []
    grouper = someDf.groupby(['Result', 'seats', 'placement'])
    for a, b in grouper:
        holder.append({"result": a[0],
                       "seats": a[1],
                       "placement": a[2],
                       "candidates": b.shape[0]})
    df = pd.DataFrame(holder)
    
    df2 = pd.pivot_table(df, index=['seats', 'result'], columns='placement', values='candidates')
    df2.fillna(0, inplace=True)
    
    return df2.astype(int)

# %%
def insideOutsideSimple(someDf):
    holder = []
    grouper = someDf.groupby(['Result', 'placement'])
    for a, b in grouper:
        holder.append({"result": a[0],
                       "placement": a[1],
                       "candidates": b.shape[0]})
    df = pd.DataFrame(holder)
    
    df2 = pd.pivot_table(df, index='result', columns='placement', values='candidates')
    df2.fillna(0, inplace=True)
    
    return df2.astype(int)

# %% [markdown]
# ## All Candidates
#
# ### Inside vs Outside, All Candidates
#
# This is the breakdown of who got elected according to whether or not they were inside or outside in either of the elections.

# %%
all_candidates =pd.concat([data[2016]['candidates'], data[2020]['candidates']])

# %%
ac = insideOutsideSimple(all_candidates)
# ac.style.bar(color='darkgoldenrod', align='zero')
ac.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_0af8b_row0_col0, #T_0af8b_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0af8b_row0_col1, #T_0af8b_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0af8b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >placement</th>
#       <th id="T_0af8b_level0_col0" class="col_heading level0 col0" >inside</th>
#       <th id="T_0af8b_level0_col1" class="col_heading level0 col1" >outside</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0af8b_level0_row0" class="row_heading level0 row0" >Elected</th>
#       <td id="T_0af8b_row0_col0" class="data row0 col0" >282</td>
#       <td id="T_0af8b_row0_col1" class="data row0 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_0af8b_level0_row1" class="row_heading level0 row1" >Not Elected</th>
#       <td id="T_0af8b_row1_col0" class="data row1 col0" >34</td>
#       <td id="T_0af8b_row1_col1" class="data row1 col1" >732</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Across the two general elections for which data is available on https://data.gov.ie/, inside candidates won 282 out of 316 seats. Nine out of every ten candidates who finished in the top three places in three-seat constituencies, the top four in four-seat constituencies or the top five in five-seat constituencies were elected.

# %% [markdown]
# ### Inside versus Outside in 2016

# %%
io2016 = insideOutsideSimple(data[2016]['candidates'])
io2016.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_63b06_row0_col0, #T_63b06_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_63b06_row0_col1, #T_63b06_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63b06">
#   <thead>
#     <tr>
#       <th class="index_name level0" >placement</th>
#       <th id="T_63b06_level0_col0" class="col_heading level0 col0" >inside</th>
#       <th id="T_63b06_level0_col1" class="col_heading level0 col1" >outside</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63b06_level0_row0" class="row_heading level0 row0" >Elected</th>
#       <td id="T_63b06_row0_col0" class="data row0 col0" >144</td>
#       <td id="T_63b06_row0_col1" class="data row0 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_63b06_level0_row1" class="row_heading level0 row1" >Not Elected</th>
#       <td id="T_63b06_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_63b06_row1_col1" class="data row1 col1" >381</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finishing inside on the first count lead to a 92% likelihood of getting elected.

# %% [markdown]
# ### Inside versus Outside in 2020

# %%
io2020 = insideOutsideSimple(data[2020]['candidates'])
io2020.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_39c71_row0_col0, #T_39c71_row1_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_39c71_row0_col1, #T_39c71_row1_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_39c71">
#   <thead>
#     <tr>
#       <th class="index_name level0" >placement</th>
#       <th id="T_39c71_level0_col0" class="col_heading level0 col0" >inside</th>
#       <th id="T_39c71_level0_col1" class="col_heading level0 col1" >outside</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39c71_level0_row0" class="row_heading level0 row0" >Elected</th>
#       <td id="T_39c71_row0_col0" class="data row0 col0" >138</td>
#       <td id="T_39c71_row0_col1" class="data row0 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_39c71_level0_row1" class="row_heading level0 row1" >Not Elected</th>
#       <td id="T_39c71_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_39c71_row1_col1" class="data row1 col1" >351</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finishing inside had an 87% likelihood of getting elected in 2020.

# %% [markdown]
# ### Inside versus Outside in Seats, All

# %%
ac_seats = insideOutside(all_candidates)
ac_seats.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_1a542_row0_col0 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_1a542_row0_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_1a542_row1_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_1a542_row1_col1 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_1a542_row2_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_1a542_row2_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_1a542_row3_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_1a542_row3_col1, #T_1a542_row4_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1a542_row4_col1, #T_1a542_row5_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1a542_row5_col1 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1a542">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >placement</th>
#       <th id="T_1a542_level0_col0" class="col_heading level0 col0" >inside</th>
#       <th id="T_1a542_level0_col1" class="col_heading level0 col1" >outside</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >seats</th>
#       <th class="index_name level1" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a542_level0_row0" class="row_heading level0 row0" rowspan="2">3</th>
#       <th id="T_1a542_level1_row0" class="row_heading level1 row0" >Elected</th>
#       <td id="T_1a542_row0_col0" class="data row0 col0" >63</td>
#       <td id="T_1a542_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_1a542_level1_row1" class="row_heading level1 row1" >Not Elected</th>
#       <td id="T_1a542_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_1a542_row1_col1" class="data row1 col1" >177</td>
#     </tr>
#     <tr>
#       <th id="T_1a542_level0_row2" class="row_heading level0 row2" rowspan="2">4</th>
#       <th id="T_1a542_level1_row2" class="row_heading level1 row2" >Elected</th>
#       <td id="T_1a542_row2_col0" class="data row2 col0" >106</td>
#       <td id="T_1a542_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_1a542_level1_row3" class="row_heading level1 row3" >Not Elected</th>
#       <td id="T_1a542_row3_col0" class="data row3 col0" >18</td>
#       <td id="T_1a542_row3_col1" class="data row3 col1" >300</td>
#     </tr>
#     <tr>
#       <th id="T_1a542_level0_row4" class="row_heading level0 row4" rowspan="2">5</th>
#       <th id="T_1a542_level1_row4" class="row_heading level1 row4" >Elected</th>
#       <td id="T_1a542_row4_col0" class="data row4 col0" >113</td>
#       <td id="T_1a542_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_1a542_level1_row5" class="row_heading level1 row5" >Not Elected</th>
#       <td id="T_1a542_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_1a542_row5_col1" class="data row5 col1" >255</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finishing inside lead to an
# - 88% likelihood of getting elected in a three-seater,
# - an 85% likelihood of getting elected in a four-seater and
# - a 94% likelihood of getting elected in a five-seater.
#
# Isn't it interesting that finishing in the first five in a five-seater in the general elections of 2016 and 2020 lead to a 94% chance of getting elected? We think of five seaters as being the most likely constituencies to elected underdogs. Perhaps not.

# %% [markdown]
# ### Inside versus Outside in Seats, 2016

# %%
io2016_seats = insideOutside(data[2016]['candidates'])
io2016_seats.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_0cd34_row0_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_0cd34_row0_col1, #T_0cd34_row1_col0, #T_0cd34_row4_col1, #T_0cd34_row5_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0cd34_row1_col1 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_0cd34_row2_col0, #T_0cd34_row3_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0cd34_row2_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_0cd34_row3_col0 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_0cd34_row4_col0 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_0cd34_row5_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0cd34">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >placement</th>
#       <th id="T_0cd34_level0_col0" class="col_heading level0 col0" >inside</th>
#       <th id="T_0cd34_level0_col1" class="col_heading level0 col1" >outside</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >seats</th>
#       <th class="index_name level1" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cd34_level0_row0" class="row_heading level0 row0" rowspan="2">3</th>
#       <th id="T_0cd34_level1_row0" class="row_heading level1 row0" >Elected</th>
#       <td id="T_0cd34_row0_col0" class="data row0 col0" >38</td>
#       <td id="T_0cd34_row0_col1" class="data row0 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_0cd34_level1_row1" class="row_heading level1 row1" >Not Elected</th>
#       <td id="T_0cd34_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_0cd34_row1_col1" class="data row1 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_0cd34_level0_row2" class="row_heading level0 row2" rowspan="2">4</th>
#       <th id="T_0cd34_level1_row2" class="row_heading level1 row2" >Elected</th>
#       <td id="T_0cd34_row2_col0" class="data row2 col0" >55</td>
#       <td id="T_0cd34_row2_col1" class="data row2 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0cd34_level1_row3" class="row_heading level1 row3" >Not Elected</th>
#       <td id="T_0cd34_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_0cd34_row3_col1" class="data row3 col1" >152</td>
#     </tr>
#     <tr>
#       <th id="T_0cd34_level0_row4" class="row_heading level0 row4" rowspan="2">5</th>
#       <th id="T_0cd34_level1_row4" class="row_heading level1 row4" >Elected</th>
#       <td id="T_0cd34_row4_col0" class="data row4 col0" >51</td>
#       <td id="T_0cd34_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_0cd34_level1_row5" class="row_heading level1 row5" >Not Elected</th>
#       <td id="T_0cd34_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_0cd34_row5_col1" class="data row5 col1" >126</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inside versus Outside in Seats, 2020

# %%
ac_seats = insideOutside(all_candidates)
ac_seats.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_a798c_row0_col0 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_a798c_row0_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_a798c_row1_col0 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_a798c_row1_col1 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_a798c_row2_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_a798c_row2_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_a798c_row3_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_a798c_row3_col1, #T_a798c_row4_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_a798c_row4_col1, #T_a798c_row5_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a798c_row5_col1 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a798c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >placement</th>
#       <th id="T_a798c_level0_col0" class="col_heading level0 col0" >inside</th>
#       <th id="T_a798c_level0_col1" class="col_heading level0 col1" >outside</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >seats</th>
#       <th class="index_name level1" >result</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a798c_level0_row0" class="row_heading level0 row0" rowspan="2">3</th>
#       <th id="T_a798c_level1_row0" class="row_heading level1 row0" >Elected</th>
#       <td id="T_a798c_row0_col0" class="data row0 col0" >63</td>
#       <td id="T_a798c_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_a798c_level1_row1" class="row_heading level1 row1" >Not Elected</th>
#       <td id="T_a798c_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_a798c_row1_col1" class="data row1 col1" >177</td>
#     </tr>
#     <tr>
#       <th id="T_a798c_level0_row2" class="row_heading level0 row2" rowspan="2">4</th>
#       <th id="T_a798c_level1_row2" class="row_heading level1 row2" >Elected</th>
#       <td id="T_a798c_row2_col0" class="data row2 col0" >106</td>
#       <td id="T_a798c_row2_col1" class="data row2 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_a798c_level1_row3" class="row_heading level1 row3" >Not Elected</th>
#       <td id="T_a798c_row3_col0" class="data row3 col0" >18</td>
#       <td id="T_a798c_row3_col1" class="data row3 col1" >300</td>
#     </tr>
#     <tr>
#       <th id="T_a798c_level0_row4" class="row_heading level0 row4" rowspan="2">5</th>
#       <th id="T_a798c_level1_row4" class="row_heading level1 row4" >Elected</th>
#       <td id="T_a798c_row4_col0" class="data row4 col0" >113</td>
#       <td id="T_a798c_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_a798c_level1_row5" class="row_heading level1 row5" >Not Elected</th>
#       <td id="T_a798c_row5_col0" class="data row5 col0" >7</td>
#       <td id="T_a798c_row5_col1" class="data row5 col1" >255</td>
#     </tr>
#   </tbody>
# </table>

# %%
elected_columns =[( 'Elected', 3),( 'Elected', 4), ( 'Elected', 5)]

# %%
def fcp(someDf):
    holder = []
    grouper = someDf.groupby(['Result', 'seats', 'first_count_position'])
    for a, b in grouper:
        holder.append({"result": a[0],
                       "seats": a[1],
                       "first count position": a[2],
                       "election": b['election'].values[0] or None,
                       "candidates": b.shape[0]})
    df = pd.DataFrame(holder)

    value_of_first_count_position_all = pd.pivot_table(df, index='first count position', columns=['result', 'seats'], values='candidates')
    value_of_first_count_position_all.fillna(0, inplace=True)
    return value_of_first_count_position_all.astype(int)

# %% [markdown]
# ## All Candidates by First Count Position
#
# Here's a breakdown of first-count-position versus seats versus elected or not elected across the two elections. Everyone who topped the poll was elected. Just one candidate who was second in a three-seater failed to get elected.
#
# Everyone who finished first, second or third in a five-seater was elected. 19 of the 24 who finished fourth were elected. 22 of the 24 who finished fifth were elected. Leapfrogging did not occur in five-seat constituencies.

# %%
x = fcp(all_candidates)
x.style.background_gradient(cmap="RdYlGn", subset=elected_columns)
# Out:
# <style type="text/css">
# #T_c7555_row0_col0, #T_c7555_row0_col1, #T_c7555_row0_col2, #T_c7555_row1_col2, #T_c7555_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c7555_row1_col0 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_c7555_row1_col1 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_c7555_row2_col0 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_c7555_row2_col1 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_c7555_row3_col0, #T_c7555_row4_col0, #T_c7555_row5_col2 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_c7555_row3_col1 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_c7555_row3_col2 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_c7555_row4_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_c7555_row4_col2 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_c7555_row5_col0, #T_c7555_row7_col0, #T_c7555_row7_col1, #T_c7555_row7_col2, #T_c7555_row8_col0, #T_c7555_row8_col1, #T_c7555_row8_col2, #T_c7555_row9_col0, #T_c7555_row9_col1, #T_c7555_row9_col2, #T_c7555_row10_col0, #T_c7555_row10_col1, #T_c7555_row10_col2, #T_c7555_row11_col0, #T_c7555_row11_col1, #T_c7555_row11_col2, #T_c7555_row12_col0, #T_c7555_row12_col1, #T_c7555_row12_col2, #T_c7555_row13_col0, #T_c7555_row13_col1, #T_c7555_row13_col2, #T_c7555_row14_col0, #T_c7555_row14_col1, #T_c7555_row14_col2, #T_c7555_row15_col0, #T_c7555_row15_col1, #T_c7555_row15_col2, #T_c7555_row16_col0, #T_c7555_row16_col1, #T_c7555_row16_col2, #T_c7555_row17_col0, #T_c7555_row17_col1, #T_c7555_row17_col2, #T_c7555_row18_col0, #T_c7555_row18_col1, #T_c7555_row18_col2, #T_c7555_row19_col0, #T_c7555_row19_col1, #T_c7555_row19_col2, #T_c7555_row20_col0, #T_c7555_row20_col1, #T_c7555_row20_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c7555_row5_col1 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_c7555_row6_col0 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_c7555_row6_col1 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_c7555_row6_col2 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c7555">
#   <thead>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th id="T_c7555_level0_col0" class="col_heading level0 col0" colspan="3">Elected</th>
#       <th id="T_c7555_level0_col3" class="col_heading level0 col3" colspan="3">Not Elected</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >seats</th>
#       <th id="T_c7555_level1_col0" class="col_heading level1 col0" >3</th>
#       <th id="T_c7555_level1_col1" class="col_heading level1 col1" >4</th>
#       <th id="T_c7555_level1_col2" class="col_heading level1 col2" >5</th>
#       <th id="T_c7555_level1_col3" class="col_heading level1 col3" >3</th>
#       <th id="T_c7555_level1_col4" class="col_heading level1 col4" >4</th>
#       <th id="T_c7555_level1_col5" class="col_heading level1 col5" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >first count position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7555_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c7555_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_c7555_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_c7555_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_c7555_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c7555_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c7555_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c7555_row1_col0" class="data row1 col0" >23</td>
#       <td id="T_c7555_row1_col1" class="data row1 col1" >28</td>
#       <td id="T_c7555_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_c7555_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_c7555_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_c7555_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c7555_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_c7555_row2_col1" class="data row2 col1" >27</td>
#       <td id="T_c7555_row2_col2" class="data row2 col2" >24</td>
#       <td id="T_c7555_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_c7555_row2_col4" class="data row2 col4" >4</td>
#       <td id="T_c7555_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c7555_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c7555_row3_col1" class="data row3 col1" >20</td>
#       <td id="T_c7555_row3_col2" class="data row3 col2" >19</td>
#       <td id="T_c7555_row3_col3" class="data row3 col3" >20</td>
#       <td id="T_c7555_row3_col4" class="data row3 col4" >11</td>
#       <td id="T_c7555_row3_col5" class="data row3 col5" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c7555_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_c7555_row4_col1" class="data row4 col1" >14</td>
#       <td id="T_c7555_row4_col2" class="data row4 col2" >22</td>
#       <td id="T_c7555_row4_col3" class="data row4 col3" >20</td>
#       <td id="T_c7555_row4_col4" class="data row4 col4" >17</td>
#       <td id="T_c7555_row4_col5" class="data row4 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c7555_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_c7555_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_c7555_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_c7555_row5_col3" class="data row5 col3" >24</td>
#       <td id="T_c7555_row5_col4" class="data row5 col4" >28</td>
#       <td id="T_c7555_row5_col5" class="data row5 col5" >20</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_c7555_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_c7555_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_c7555_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_c7555_row6_col3" class="data row6 col3" >22</td>
#       <td id="T_c7555_row6_col4" class="data row6 col4" >30</td>
#       <td id="T_c7555_row6_col5" class="data row6 col5" >21</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_c7555_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_c7555_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_c7555_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_c7555_row7_col3" class="data row7 col3" >23</td>
#       <td id="T_c7555_row7_col4" class="data row7 col4" >31</td>
#       <td id="T_c7555_row7_col5" class="data row7 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_c7555_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_c7555_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_c7555_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_c7555_row8_col3" class="data row8 col3" >23</td>
#       <td id="T_c7555_row8_col4" class="data row8 col4" >31</td>
#       <td id="T_c7555_row8_col5" class="data row8 col5" >24</td>
#     </tr>
#     <tr>
#       <th id="T_c7555_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_c7555_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_c7555_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_c7555_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_c7555_row9_col3" class="data row9 col3" >18</td>
#       <td id="T_c7555_row9_col4" class="data row9 col4" >31</td>
#       <td id="T_c7555_row9_

# %% [markdown]
# ## 2016 Candidates by First Count Position

# %%
x = fcp(data[2016]['candidates'])
x.style.background_gradient(cmap="RdYlGn", subset=elected_columns)
# Out:
# <style type="text/css">
# #T_3b1db_row0_col0, #T_3b1db_row0_col1, #T_3b1db_row0_col2, #T_3b1db_row1_col0, #T_3b1db_row1_col2, #T_3b1db_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_3b1db_row1_col1, #T_3b1db_row2_col1 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_3b1db_row2_col0 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_3b1db_row3_col0 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_3b1db_row3_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_3b1db_row3_col2 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_3b1db_row4_col0, #T_3b1db_row6_col0 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_3b1db_row4_col1 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_3b1db_row4_col2 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_3b1db_row5_col0, #T_3b1db_row5_col1, #T_3b1db_row6_col1, #T_3b1db_row7_col0, #T_3b1db_row7_col1, #T_3b1db_row7_col2, #T_3b1db_row8_col0, #T_3b1db_row8_col1, #T_3b1db_row8_col2, #T_3b1db_row9_col0, #T_3b1db_row9_col1, #T_3b1db_row9_col2, #T_3b1db_row10_col0, #T_3b1db_row10_col1, #T_3b1db_row10_col2, #T_3b1db_row11_col0, #T_3b1db_row11_col1, #T_3b1db_row11_col2, #T_3b1db_row12_col0, #T_3b1db_row12_col1, #T_3b1db_row12_col2, #T_3b1db_row13_col0, #T_3b1db_row13_col1, #T_3b1db_row13_col2, #T_3b1db_row14_col0, #T_3b1db_row14_col1, #T_3b1db_row14_col2, #T_3b1db_row15_col0, #T_3b1db_row15_col1, #T_3b1db_row15_col2, #T_3b1db_row16_col0, #T_3b1db_row16_col1, #T_3b1db_row16_col2, #T_3b1db_row17_col0, #T_3b1db_row17_col1, #T_3b1db_row17_col2, #T_3b1db_row18_col0, #T_3b1db_row18_col1, #T_3b1db_row18_col2, #T_3b1db_row19_col0, #T_3b1db_row19_col1, #T_3b1db_row19_col2, #T_3b1db_row20_col0, #T_3b1db_row20_col1, #T_3b1db_row20_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_3b1db_row5_col2 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_3b1db_row6_col2 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3b1db">
#   <thead>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th id="T_3b1db_level0_col0" class="col_heading level0 col0" colspan="3">Elected</th>
#       <th id="T_3b1db_level0_col3" class="col_heading level0 col3" colspan="3">Not Elected</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >seats</th>
#       <th id="T_3b1db_level1_col0" class="col_heading level1 col0" >3</th>
#       <th id="T_3b1db_level1_col1" class="col_heading level1 col1" >4</th>
#       <th id="T_3b1db_level1_col2" class="col_heading level1 col2" >5</th>
#       <th id="T_3b1db_level1_col3" class="col_heading level1 col3" >3</th>
#       <th id="T_3b1db_level1_col4" class="col_heading level1 col4" >4</th>
#       <th id="T_3b1db_level1_col5" class="col_heading level1 col5" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >first count position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b1db_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_3b1db_row0_col0" class="data row0 col0" >14</td>
#       <td id="T_3b1db_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_3b1db_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_3b1db_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3b1db_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3b1db_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_3b1db_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_3b1db_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_3b1db_row1_col2" class="data row1 col2" >11</td>
#       <td id="T_3b1db_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_3b1db_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_3b1db_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_3b1db_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_3b1db_row2_col1" class="data row2 col1" >14</td>
#       <td id="T_3b1db_row2_col2" class="data row2 col2" >11</td>
#       <td id="T_3b1db_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_3b1db_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_3b1db_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_3b1db_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_3b1db_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_3b1db_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_3b1db_row3_col3" class="data row3 col3" >12</td>
#       <td id="T_3b1db_row3_col4" class="data row3 col4" >3</td>
#       <td id="T_3b1db_row3_col5" class="data row3 col5" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_3b1db_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_3b1db_row4_col1" class="data row4 col1" >5</td>
#       <td id="T_3b1db_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_3b1db_row4_col3" class="data row4 col3" >13</td>
#       <td id="T_3b1db_row4_col4" class="data row4 col4" >10</td>
#       <td id="T_3b1db_row4_col5" class="data row4 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_3b1db_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_3b1db_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_3b1db_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_3b1db_row5_col3" class="data row5 col3" >14</td>
#       <td id="T_3b1db_row5_col4" class="data row5 col4" >15</td>
#       <td id="T_3b1db_row5_col5" class="data row5 col5" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_3b1db_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_3b1db_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_3b1db_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_3b1db_row6_col3" class="data row6 col3" >12</td>
#       <td id="T_3b1db_row6_col4" class="data row6 col4" >15</td>
#       <td id="T_3b1db_row6_col5" class="data row6 col5" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_3b1db_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_3b1db_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_3b1db_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_3b1db_row7_col3" class="data row7 col3" >13</td>
#       <td id="T_3b1db_row7_col4" class="data row7 col4" >15</td>
#       <td id="T_3b1db_row7_col5" class="data row7 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_3b1db_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_3b1db_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_3b1db_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_3b1db_row8_col3" class="data row8 col3" >13</td>
#       <td id="T_3b1db_row8_col4" class="data row8 col4" >15</td>
#       <td id="T_3b1db_row8_col5" class="data row8 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_3b1db_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_3b1db_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_3b1db_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_3b1db_row9_col3" class="data row9 col3" >10</td>
#       <td id="T_3b1db_row9_col4" class="data row9 col4" >15</td>
#       <td id="T_3b1db_row9_col5" class="data row9 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_3b1db_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_3b1

# %% [markdown]
# ## 2020 Candidates by First Count Position

# %%
x = fcp(data[2020]['candidates'])
x.style.background_gradient(cmap="RdYlGn", subset=elected_columns)
# Out:
# <style type="text/css">
# #T_725d2_row0_col0, #T_725d2_row0_col1, #T_725d2_row0_col2, #T_725d2_row1_col2, #T_725d2_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_725d2_row1_col0 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_725d2_row1_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_725d2_row2_col0 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_725d2_row2_col1 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_725d2_row3_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_725d2_row3_col1 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_725d2_row3_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_725d2_row4_col0 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_725d2_row4_col1 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_725d2_row4_col2 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_725d2_row5_col0, #T_725d2_row6_col0, #T_725d2_row7_col0, #T_725d2_row7_col1, #T_725d2_row7_col2, #T_725d2_row8_col0, #T_725d2_row8_col1, #T_725d2_row8_col2, #T_725d2_row9_col0, #T_725d2_row9_col1, #T_725d2_row9_col2, #T_725d2_row10_col0, #T_725d2_row10_col1, #T_725d2_row10_col2, #T_725d2_row11_col0, #T_725d2_row11_col1, #T_725d2_row11_col2, #T_725d2_row12_col0, #T_725d2_row12_col1, #T_725d2_row12_col2, #T_725d2_row13_col0, #T_725d2_row13_col1, #T_725d2_row13_col2, #T_725d2_row14_col0, #T_725d2_row14_col1, #T_725d2_row14_col2, #T_725d2_row15_col0, #T_725d2_row15_col1, #T_725d2_row15_col2, #T_725d2_row16_col0, #T_725d2_row16_col1, #T_725d2_row16_col2, #T_725d2_row17_col0, #T_725d2_row17_col1, #T_725d2_row17_col2, #T_725d2_row18_col0, #T_725d2_row18_col1, #T_725d2_row18_col2, #T_725d2_row19_col0, #T_725d2_row19_col1, #T_725d2_row19_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_725d2_row5_col1 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_725d2_row5_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_725d2_row6_col1 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_725d2_row6_col2 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_725d2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >result</th>
#       <th id="T_725d2_level0_col0" class="col_heading level0 col0" colspan="3">Elected</th>
#       <th id="T_725d2_level0_col3" class="col_heading level0 col3" colspan="3">Not Elected</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >seats</th>
#       <th id="T_725d2_level1_col0" class="col_heading level1 col0" >3</th>
#       <th id="T_725d2_level1_col1" class="col_heading level1 col1" >4</th>
#       <th id="T_725d2_level1_col2" class="col_heading level1 col2" >5</th>
#       <th id="T_725d2_level1_col3" class="col_heading level1 col3" >3</th>
#       <th id="T_725d2_level1_col4" class="col_heading level1 col4" >4</th>
#       <th id="T_725d2_level1_col5" class="col_heading level1 col5" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >first count position</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_725d2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_725d2_row0_col0" class="data row0 col0" >10</td>
#       <td id="T_725d2_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_725d2_row0_col2" class="data row0 col2" >13</td>
#       <td id="T_725d2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_725d2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_725d2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_725d2_row1_col0" class="data row1 col0" >9</td>
#       <td id="T_725d2_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_725d2_row1_col2" class="data row1 col2" >13</td>
#       <td id="T_725d2_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_725d2_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_725d2_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_725d2_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_725d2_row2_col1" class="data row2 col1" >13</td>
#       <td id="T_725d2_row2_col2" class="data row2 col2" >13</td>
#       <td id="T_725d2_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_725d2_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_725d2_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_725d2_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_725d2_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_725d2_row3_col2" class="data row3 col2" >11</td>
#       <td id="T_725d2_row3_col3" class="data row3 col3" >8</td>
#       <td id="T_725d2_row3_col4" class="data row3 col4" >8</td>
#       <td id="T_725d2_row3_col5" class="data row3 col5" >2</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_725d2_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_725d2_row4_col1" class="data row4 col1" >9</td>
#       <td id="T_725d2_row4_col2" class="data row4 col2" >12</td>
#       <td id="T_725d2_row4_col3" class="data row4 col3" >7</td>
#       <td id="T_725d2_row4_col4" class="data row4 col4" >7</td>
#       <td id="T_725d2_row4_col5" class="data row4 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_725d2_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_725d2_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_725d2_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_725d2_row5_col3" class="data row5 col3" >10</td>
#       <td id="T_725d2_row5_col4" class="data row5 col4" >13</td>
#       <td id="T_725d2_row5_col5" class="data row5 col5" >12</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_725d2_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_725d2_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_725d2_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_725d2_row6_col3" class="data row6 col3" >10</td>
#       <td id="T_725d2_row6_col4" class="data row6 col4" >15</td>
#       <td id="T_725d2_row6_col5" class="data row6 col5" >11</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_725d2_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_725d2_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_725d2_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_725d2_row7_col3" class="data row7 col3" >10</td>
#       <td id="T_725d2_row7_col4" class="data row7 col4" >16</td>
#       <td id="T_725d2_row7_col5" class="data row7 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_725d2_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_725d2_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_725d2_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_725d2_row8_col3" class="data row8 col3" >10</td>
#       <td id="T_725d2_row8_col4" class="data row8 col4" >16</td>
#       <td id="T_725d2_row8_col5" class="data row8 col5" >13</td>
#     </tr>
#     <tr>
#       <th id="T_725d2_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_725d2_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_725d2_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_725d2_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_725d2_row9_col3" class="data row9 col3" >8</td>
#       <td id="T_725d2_row9_col4" class="data row9 col4" >16</td>
#       <td id="T_725d2_row9_col5" class="data row9
