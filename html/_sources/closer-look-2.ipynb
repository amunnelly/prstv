# %% [markdown]
# # A Closer Look at Some Atypical Constituencies

# %%
import pandas as pd
import altair as alt
import pickle

# %%
with open("data.pkl", "rb") as f: data = pickle.load(f)

# %% [markdown]
# Identify Elected TDs

# %%
elected = {}
notelected = {}
for year in (2016, 2020):
    temp = data[year]['candidates'].copy()
    for a, b in temp.iterrows():
        if b['Result'] == 'Elected':
            elected[b['key']]=b['name']
        else:
            notelected[b['key']]=b['name']

# %%
def elected_tagger(someDf):
    """
    A helper function to dress up the count data frames by making which TDs were elected
    more visible.
    """
    candidates = []
    for a, b in someDf.iterrows():
        if b['key'] in elected:
            candidates.append("".join(["*", elected[b['key']]]))
        else:
            candidates.append(notelected[b['key']])
    return candidates

# %%
def get_count_details(someDf, conNumber):
    details = someDf[someDf['Constituency Number']==conNumber].copy()
    details['Candidate'] = elected_tagger(details)
    pivot = pd.pivot_table(details, index='Candidate', columns='Count Number', values='Total Votes')
    return pivot.sort_values(1, ascending=False)

# %%
def set_categorical_data(someIndex):
    holder = []
    for i in someIndex:
        holder.append(" ".join(i))
    return holder

# %%
def prepare_chart_data(data):
    holder = []
    candidates = set_categorical_data(data.index)
    for i in data.index:
        for c in data.columns:
            holder.append({"candidate": " ".join(i),
                           "count": c,
                           "votes": data.loc[i][c]})
    temp = pd.DataFrame(holder)
    temp['candidate'] = pd.Categorical(temp['candidate'], candidates, ordered=True)
    return temp

# %%
def charter(count_details):
    chart_data = prepare_chart_data(count_details)

    label_data = chart_data[(chart_data['count']==1)&((chart_data['votes']>=chart_data.votes.mean()))].copy()

    lines = alt.Chart(chart_data).mark_line().encode(
        x='count:O',
        y='votes',
        color='candidate',
    tooltip=chart_data.columns.to_list()).properties(width=500)

    points = alt.Chart(label_data).mark_circle().encode(
        x='count:O',
        y='votes')

    labels = points.mark_text(align="left").encode(text='candidate')

    return lines + labels

# %% [markdown]
# ## Cork South West, 2020
#
# Social Democrat leader Holly Cairns is the most charismatic politician in the Dáil but she was very lucky to get elected in the first place. In fifth place and over a thousand votes behind third place on the first count, Cairns proved more transfer-friendly than Sinn Féin's Paul Hayes and saw her move to fourth. Then, on Hayes's elimination, Cairns got over three thousand of Hayes votes, while Tom Lombard got 393. And that made all the difference.

# %%
count_details = get_count_details(data[2020]['count'], 8)
count_details.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_6cf38_row0_col0, #T_6cf38_row0_col1, #T_6cf38_row0_col2, #T_6cf38_row0_col3, #T_6cf38_row0_col4, #T_6cf38_row0_col5, #T_6cf38_row0_col6, #T_6cf38_row1_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_6cf38_row0_col7 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_6cf38_row1_col0, #T_6cf38_row2_col1 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_6cf38_row1_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_6cf38_row1_col2 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_6cf38_row1_col3, #T_6cf38_row4_col5 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_6cf38_row1_col4 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_6cf38_row1_col5 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_6cf38_row1_col6 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_6cf38_row2_col0, #T_6cf38_row3_col5 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_6cf38_row2_col2, #T_6cf38_row4_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_6cf38_row2_col3 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_6cf38_row2_col4 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_6cf38_row2_col5 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_6cf38_row2_col6 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_6cf38_row2_col7 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_6cf38_row3_col0 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_6cf38_row3_col1, #T_6cf38_row5_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_6cf38_row3_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_6cf38_row3_col3 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_6cf38_row3_col4 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_6cf38_row3_col6 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_6cf38_row3_col7, #T_6cf38_row5_col6, #T_6cf38_row5_col7, #T_6cf38_row6_col5, #T_6cf38_row6_col6, #T_6cf38_row6_col7, #T_6cf38_row7_col4, #T_6cf38_row7_col5, #T_6cf38_row7_col6, #T_6cf38_row7_col7, #T_6cf38_row8_col3, #T_6cf38_row8_col4, #T_6cf38_row8_col5, #T_6cf38_row8_col6, #T_6cf38_row8_col7, #T_6cf38_row9_col2, #T_6cf38_row9_col3, #T_6cf38_row9_col4, #T_6cf38_row9_col5, #T_6cf38_row9_col6, #T_6cf38_row9_col7, #T_6cf38_row10_col2, #T_6cf38_row10_col3, #T_6cf38_row10_col4, #T_6cf38_row10_col5, #T_6cf38_row10_col6, #T_6cf38_row10_col7, #T_6cf38_row11_col0, #T_6cf38_row11_col1, #T_6cf38_row11_col2, #T_6cf38_row11_col3, #T_6cf38_row11_col4, #T_6cf38_row11_col5, #T_6cf38_row11_col6, #T_6cf38_row11_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_6cf38_row4_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_6cf38_row4_col1 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_6cf38_row4_col2 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_6cf38_row4_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_6cf38_row4_col6 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_6cf38_row4_col7 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_6cf38_row5_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_6cf38_row5_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_6cf38_row5_col2 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_6cf38_row5_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_6cf38_row5_col4 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_6cf38_row6_col0 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_6cf38_row6_col1 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_6cf38_row6_col2 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_6cf38_row6_col3 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_6cf38_row6_col4 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_6cf38_row7_col0 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_6cf38_row7_col1 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_6cf38_row7_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_6cf38_row7_col3 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_6cf38_row8_col0 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_6cf38_row8_col1 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_6cf38_row8_col2 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_6cf38_row9_col0 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_6cf38_row9_col1 {
#   background-color: #bb1526;
#   color: #f1f1f1;
# }
# #T_6cf38_row10_col0 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_6cf38_row10_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6cf38">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Count Number</th>
#       <th id="T_6cf38_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_6cf38_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_6cf38_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_6cf38_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_6cf38_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_6cf38_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_6cf38_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_6cf38_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Candidate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cf38_level0_row0" class="row_heading level0 row0" >*Michael Collins, NON-P.</th>
#       <td id="T_6cf38_row0_col0" class="data row0 col0" >11712</td>
#       <td id="T_6cf38_row0_col1" class="data row0 col1" >11085</td>
#       <td id="T_6cf38_row0_col2" class="data row0 col2" >11085</td>
#       <td id="T_6cf38_row0_col3" class="data row0 col3" >11085</td>
#       <td id="T_6cf38_row0_col4" class="data row0 col4" >11085</td>
#       <td id="T_6cf38_row0_col5" class="data row0 col5" >11085</td>
#       <td id="T_6cf38_row0_col6" class="data row0 col6" >11085</td>
#       <td id="T_6cf38_row0_col7" class="data row0 col7" >11085</td>
#     </tr>
#     <tr>
#       <th id="T_6cf38_level0_row1" class="row_heading level0 row1" >*Christopher O'Sullivan, F.F.</th>
#       <td id="T_6cf38_row1_col0" class="data row1 col0" >6262</td>
#       <td id="T_6cf38_row1_col1" class="data row1 col1" >6400</td>
#       <td id="T_6cf38_row1_col2" class="data row1 col2" >6503</td>
#       <td id="T_6cf38_row1_col3" class="data row1 col3" >6602</td>
#       <td id="T_6cf38_row1_col4" class="data row1 col4" >6960</td>
#       <td id="T_6cf38_row1_col5" class="data row1 col5" >7228</td>
#       <td id="T_6cf38_row1_col6" class="data row1 col6" >10273</td>
#       <td id="T_6cf38_row1_col7" class="data row1 col7" >11262</td>
#     </tr>
#     <tr>
#       <th id="T_6cf38_level0_row2" class="row_heading level0 row2" >Tim Lombard, F.G.</th>
#       <td id="T_6cf38_row2_col0" class="data row2 col0" >5865</td>
#       <td id="T_6cf38_row2_col1" class="data row2 col1" >5917</td>
#       <td id="T_6cf38_row2_col2" class="data row2 col2" >5982</td>
#       <td id="T_6cf38_row2_col3" class="data row2 col3" >6170</td>
#       <td id="T_6cf38_row2_col4" class="data row2 col4" >6669</td>
#       <td id="T_6cf38_row2_col5" class="data row2 col5" >8557</td>
#       <td id="T_6cf38_row2_col6" class="data row2 col6" >9133</td>
#       <td id="T_6cf38_row2_col7" class="data row2 col7" >9526</td>
#     </tr>
#     <tr>
#       <th id="T_6cf38_level0_row3" class="row_heading level0 row3" >Paul Hayes, S.F.</th>
#       <td id="T_6cf38_row3_col0" class="data row3 col0" >4777</td>
#       <td id="T_6cf38_row3_col1" class="data row3 col1" >4881</td>
#       <td id="T_6cf38_row3_col2" class="data row3 col2" >5075</td>
#       <td id="T_6cf38_row3_col3" class="data row3 col3" >5229</td>
#       <td id="T_6cf38_row3_col4" class="data row3 col4" >5462</t

# %%
charter(count_details)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Galway East, 2020
#
# Sinn Féin's Louis O'Hara is one of only three candidates in the 2020 General Election to come second in first-preference voting and yet not be elected. How did that happen? It happened because Anne Rabbitte benefitted from a strong FF transfer on Donagh Mark Killelea's elimination after the fifth count, and Ciaran Cannon from a strong FG transfer on elimination of Peter Roche on the sixth count. Also, Mr O'Hara is only 21, which is a very, very young age for someone running for the Dáil. Louis O'Hara's loss was, I would argue, as anomalous as Holly Cairns's win.

# %%
count_details = get_count_details(data[2020]['count'], 22)
count_details.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_75838_row0_col0, #T_75838_row0_col1, #T_75838_row0_col2, #T_75838_row0_col3, #T_75838_row0_col4, #T_75838_row0_col5, #T_75838_row0_col6, #T_75838_row2_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_75838_row0_col7 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_75838_row1_col0, #T_75838_row1_col1 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_75838_row1_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_75838_row1_col3, #T_75838_row4_col7 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_75838_row1_col4 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_75838_row1_col5, #T_75838_row1_col7 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_75838_row1_col6, #T_75838_row3_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_75838_row2_col0 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_75838_row2_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_75838_row2_col2, #T_75838_row4_col6 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_75838_row2_col3 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_75838_row2_col4 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_75838_row2_col5 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_75838_row2_col6 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_75838_row3_col0 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_75838_row3_col2 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_75838_row3_col3 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_75838_row3_col4 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_75838_row3_col5 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_75838_row3_col6, #T_75838_row3_col7, #T_75838_row5_col5, #T_75838_row5_col6, #T_75838_row5_col7, #T_75838_row6_col4, #T_75838_row6_col5, #T_75838_row6_col6, #T_75838_row6_col7, #T_75838_row7_col3, #T_75838_row7_col4, #T_75838_row7_col5, #T_75838_row7_col6, #T_75838_row7_col7, #T_75838_row8_col3, #T_75838_row8_col4, #T_75838_row8_col5, #T_75838_row8_col6, #T_75838_row8_col7, #T_75838_row9_col2, #T_75838_row9_col3, #T_75838_row9_col4, #T_75838_row9_col5, #T_75838_row9_col6, #T_75838_row9_col7, #T_75838_row10_col1, #T_75838_row10_col2, #T_75838_row10_col3, #T_75838_row10_col4, #T_75838_row10_col5, #T_75838_row10_col6, #T_75838_row10_col7, #T_75838_row11_col0, #T_75838_row11_col1, #T_75838_row11_col2, #T_75838_row11_col3, #T_75838_row11_col4, #T_75838_row11_col5, #T_75838_row11_col6, #T_75838_row11_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_75838_row4_col0, #T_75838_row4_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_75838_row4_col2, #T_75838_row4_col3 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_75838_row4_col4 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_75838_row4_col5 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_75838_row5_col0, #T_75838_row5_col1 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_75838_row5_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_75838_row5_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_75838_row5_col4 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_75838_row6_col0 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_75838_row6_col1, #T_75838_row6_col2 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_75838_row6_col3 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_75838_row7_col0 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_75838_row7_col1, #T_75838_row7_col2 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_75838_row8_col0 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_75838_row8_col1, #T_75838_row8_col2 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_75838_row9_col0 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_75838_row9_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_75838_row10_col0 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_75838">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Count Number</th>
#       <th id="T_75838_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_75838_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_75838_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_75838_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_75838_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_75838_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_75838_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_75838_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Candidate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75838_level0_row0" class="row_heading level0 row0" >*Seán CANNEY, NON-P.</th>
#       <td id="T_75838_row0_col0" class="data row0 col0" >7815</td>
#       <td id="T_75838_row0_col1" class="data row0 col1" >7894</td>
#       <td id="T_75838_row0_col2" class="data row0 col2" >8142</td>
#       <td id="T_75838_row0_col3" class="data row0 col3" >8331</td>
#       <td id="T_75838_row0_col4" class="data row0 col4" >8785</td>
#       <td id="T_75838_row0_col5" class="data row0 col5" >9896</td>
#       <td id="T_75838_row0_col6" class="data row0 col6" >12292</td>
#       <td id="T_75838_row0_col7" class="data row0 col7" >10631</td>
#     </tr>
#     <tr>
#       <th id="T_75838_level0_row1" class="row_heading level0 row1" >Louis O'HARA, S.F.</th>
#       <td id="T_75838_row1_col0" class="data row1 col0" >7108</td>
#       <td id="T_75838_row1_col1" class="data row1 col1" >7177</td>
#       <td id="T_75838_row1_col2" class="data row1 col2" >7294</td>
#       <td id="T_75838_row1_col3" class="data row1 col3" >7649</td>
#       <td id="T_75838_row1_col4" class="data row1 col4" >8441</td>
#       <td id="T_75838_row1_col5" class="data row1 col5" >8799</td>
#       <td id="T_75838_row1_col6" class="data row1 col6" >9411</td>
#       <td id="T_75838_row1_col7" class="data row1 col7" >9685</td>
#     </tr>
#     <tr>
#       <th id="T_75838_level0_row2" class="row_heading level0 row2" >*Ciaran CANNON, F.G.</th>
#       <td id="T_75838_row2_col0" class="data row2 col0" >6298</td>
#       <td id="T_75838_row2_col1" class="data row2 col1" >6307</td>
#       <td id="T_75838_row2_col2" class="data row2 col2" >6326</td>
#       <td id="T_75838_row2_col3" class="data row2 col3" >6536</td>
#       <td id="T_75838_row2_col4" class="data row2 col4" >7114</td>
#       <td id="T_75838_row2_col5" class="data row2 col5" >7425</td>
#       <td id="T_75838_row2_col6" class="data row2 col6" >9990</td>
#       <td id="T_75838_row2_col7" class="data row2 col7" >10890</td>
#     </tr>
#     <tr>
#       <th id="T_75838_level0_row3" class="row_heading level0 row3" >Peter ROCHE, F.G.</th>
#       <td id="T_75838_row3_col0" class="data row3 col0" >6034</td>
#       <td id="T_75838_row3_col1" class="data row3 col1" >6040</td>
#       <td id="T_75838_row3_col2" class="data row3 col2" >6090</td>
#       <td id="T_75838_row3_col3" class="data row3 col3" >6180</td>
#       <td id="T_75838_row3_col4" class="data row3 col4" >6392</td>
#       <td id="T_75838_row3_col5" class="data row3 col5" >6973</td>
#       <td id="T_75838_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_75838_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_75838_level0_row4" class="row_heading level0 row4" >*Anne RABBITTE, F.F.</th>
#       <td id="T_75838_row4_col0" class="data row4 col0" >5762</td>
#       <td id="T_75838_row4_col1" class="data row4 col1" >5776</td>
#       <td id="T_75838_row4_col2" class="data row4 col2" >5820</td>
#       <td id="T_75838_row4_col3" class="data row4 col3"

# %%
charter(count_details)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Dublin South Central, 2020
#
# Dublin South Central is unique in that, of the 79 constituencies surveyed across 2016 and 2020, Dublin South Central 2020 is the only constituency to return two TDs who were outside the top four candidates on the first count. The reason is the huge transfer that Bríd Smith and Joan Collins enjoyed from the distribution of Aengus Ó Snodaigh's huge quota, just short of a surplus in itself.
#
# The question is: were Catherine Byrne and Catherine Ardagh transfer-toxic, or was it their low first-count vote that did for them?

# %%
count_details = get_count_details(data[2020]['count'], 16)
count_details.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_4ca7e_row0_col0, #T_4ca7e_row0_col2, #T_4ca7e_row0_col3, #T_4ca7e_row0_col4, #T_4ca7e_row0_col5, #T_4ca7e_row3_col1, #T_4ca7e_row3_col2, #T_4ca7e_row3_col3, #T_4ca7e_row3_col4, #T_4ca7e_row3_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4ca7e_row0_col1 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_4ca7e_row1_col0 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_4ca7e_row1_col1, #T_4ca7e_row4_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_4ca7e_row1_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_4ca7e_row1_col3 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_4ca7e_row1_col4 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_4ca7e_row1_col5 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_4ca7e_row2_col0, #T_4ca7e_row3_col0 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_4ca7e_row2_col1 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_4ca7e_row2_col2 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_4ca7e_row2_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_4ca7e_row2_col4 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_4ca7e_row2_col5, #T_4ca7e_row6_col4, #T_4ca7e_row6_col5, #T_4ca7e_row7_col4, #T_4ca7e_row7_col5, #T_4ca7e_row8_col3, #T_4ca7e_row8_col4, #T_4ca7e_row8_col5, #T_4ca7e_row9_col3, #T_4ca7e_row9_col4, #T_4ca7e_row9_col5, #T_4ca7e_row10_col3, #T_4ca7e_row10_col4, #T_4ca7e_row10_col5, #T_4ca7e_row11_col0, #T_4ca7e_row11_col3, #T_4ca7e_row11_col4, #T_4ca7e_row11_col5, #T_4ca7e_row12_col0, #T_4ca7e_row12_col1, #T_4ca7e_row12_col2, #T_4ca7e_row12_col3, #T_4ca7e_row12_col4, #T_4ca7e_row12_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4ca7e_row4_col0 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_4ca7e_row4_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_4ca7e_row4_col2 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_4ca7e_row4_col4 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_4ca7e_row4_col5 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_4ca7e_row5_col0 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_4ca7e_row5_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_4ca7e_row5_col2 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_4ca7e_row5_col3 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_4ca7e_row5_col4 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_4ca7e_row5_col5 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_4ca7e_row6_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_4ca7e_row6_col1 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_4ca7e_row6_col2 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_4ca7e_row6_col3 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_4ca7e_row7_col0 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_4ca7e_row7_col1 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_4ca7e_row7_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_4ca7e_row7_col3 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_4ca7e_row8_col0 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_4ca7e_row8_col1 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_4ca7e_row8_col2 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_4ca7e_row9_col0 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_4ca7e_row9_col1 {
#   background-color: #b71126;
#   color: #f1f1f1;
# }
# #T_4ca7e_row9_col2 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_4ca7e_row10_col0, #T_4ca7e_row11_col1, #T_4ca7e_row11_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_4ca7e_row10_col1 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_4ca7e_row10_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4ca7e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Count Number</th>
#       <th id="T_4ca7e_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_4ca7e_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_4ca7e_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_4ca7e_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_4ca7e_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_4ca7e_level0_col5" class="col_heading level0 col5" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Candidate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ca7e_level0_row0" class="row_heading level0 row0" >*Aengus Ó'Snodaigh, S.F.</th>
#       <td id="T_4ca7e_row0_col0" class="data row0 col0" >17015</td>
#       <td id="T_4ca7e_row0_col1" class="data row0 col1" >8659</td>
#       <td id="T_4ca7e_row0_col2" class="data row0 col2" >8659</td>
#       <td id="T_4ca7e_row0_col3" class="data row0 col3" >8659</td>
#       <td id="T_4ca7e_row0_col4" class="data row0 col4" >8659</td>
#       <td id="T_4ca7e_row0_col5" class="data row0 col5" >8659</td>
#     </tr>
#     <tr>
#       <th id="T_4ca7e_level0_row1" class="row_heading level0 row1" >Catherine Byrne, F.G.</th>
#       <td id="T_4ca7e_row1_col0" class="data row1 col0" >5078</td>
#       <td id="T_4ca7e_row1_col1" class="data row1 col1" >5192</td>
#       <td id="T_4ca7e_row1_col2" class="data row1 col2" >5202</td>
#       <td id="T_4ca7e_row1_col3" class="data row1 col3" >5275</td>
#       <td id="T_4ca7e_row1_col4" class="data row1 col4" >5788</td>
#       <td id="T_4ca7e_row1_col5" class="data row1 col5" >7431</td>
#     </tr>
#     <tr>
#       <th id="T_4ca7e_level0_row2" class="row_heading level0 row2" >Catherine Ardagh, F.F.</th>
#       <td id="T_4ca7e_row2_col0" class="data row2 col0" >4782</td>
#       <td id="T_4ca7e_row2_col1" class="data row2 col1" >5013</td>
#       <td id="T_4ca7e_row2_col2" class="data row2 col2" >5030</td>
#       <td id="T_4ca7e_row2_col3" class="data row2 col3" >5184</td>
#       <td id="T_4ca7e_row2_col4" class="data row2 col4" >5598</td>
#       <td id="T_4ca7e_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4ca7e_level0_row3" class="row_heading level0 row3" >*Bríd Smith, S.P.B.P.</th>
#       <td id="T_4ca7e_row3_col0" class="data row3 col0" >4753</td>
#       <td id="T_4ca7e_row3_col1" class="data row3 col1" >9547</td>
#       <td id="T_4ca7e_row3_col2" class="data row3 col2" >8659</td>
#       <td id="T_4ca7e_row3_col3" class="data row3 col3" >8659</td>
#       <td id="T_4ca7e_row3_col4" class="data row3 col4" >8659</td>
#       <td id="T_4ca7e_row3_col5" class="data row3 col5" >8659</td>
#     </tr>
#     <tr>
#       <th id="T_4ca7e_level0_row4" class="row_heading level0 row4" >*Patrick Costello, G.P.</th>
#       <td id="T_4ca7e_row4_col0" class="data row4 col0" >4041</td>
#       <td id="T_4ca7e_row4_col1" class="data row4 col1" >4449</td>
#       <td id="T_4ca7e_row4_col2" class="data row4 col2" >4522</td>
#       <td id="T_4ca7e_row4_col3" class="data row4 col3" >4698</td>
#       <td id="T_4ca7e_row4_col4" class="data row4 col4" >6917</td>
#       <td id="T_4ca7e_row4_col5" class="data row4 col5" >8582</td>
#     </tr>
#     <tr>
#       <th id="T_4ca7e_level0_row5" class="row_heading level0 row5" >*Joan Collins, I.4.C.</th>
#       <td id="T_4ca7e_row5_col0" class="data row5 col0" >2831</td>
#       <td id="T_4ca7e_row5_col1" class="data row5 col1" >4578</td>
#       <td id="T_4ca7e_row5_col2" class="data row5 col2" >5076</td>
#       <td id="T_4ca7e_row5_col3" class="data row5 col3" >5552</td>
#       <td id="T_4ca7e_row5_col4" class="data row5 col4" >6654</td>
#       <td id="T_4ca7e_row5_col5" class="data row5 col5" >7807</td>
#     </tr>
#     <tr>
#       <th id="T_4ca7e_level0_row6" class="row_heading level0 row6" >Rebecca Moynihan, LAB.</th>
#       <td id="T_4ca7e_row6_col0" class="data row6 col0" >2095</td>
#       <td id="T_4ca7e_row6_col1" class="data row6 col1" >2330</td>
#       <td id="T_4ca7e_row6_col2" class="data row6 c

# %%
charter(count_details)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Dublin Rathdown, 2016
#
# The elimination of Mary White saw over two thousand votes transfer to Catherine Martin of the Greens and only six-hundred odd to former Minister for Justice Alan Shatter. That was the end of him.

# %%
count_details = get_count_details(data[2016]['count'], 18)
count_details.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_7475e_row0_col0, #T_7475e_row0_col1, #T_7475e_row0_col2, #T_7475e_row0_col3, #T_7475e_row0_col4, #T_7475e_row0_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7475e_row1_col0 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_7475e_row1_col1 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_7475e_row1_col2 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_7475e_row1_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_7475e_row1_col4 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_7475e_row1_col5 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_7475e_row2_col0 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_7475e_row2_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_7475e_row2_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_7475e_row2_col3 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_7475e_row2_col4 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_7475e_row2_col5 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_7475e_row3_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_7475e_row3_col1, #T_7475e_row4_col1 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_7475e_row3_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_7475e_row3_col3 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_7475e_row3_col4 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_7475e_row3_col5, #T_7475e_row5_col4, #T_7475e_row5_col5, #T_7475e_row6_col3, #T_7475e_row6_col4, #T_7475e_row6_col5, #T_7475e_row7_col2, #T_7475e_row7_col3, #T_7475e_row7_col4, #T_7475e_row7_col5, #T_7475e_row8_col0, #T_7475e_row8_col1, #T_7475e_row8_col2, #T_7475e_row8_col3, #T_7475e_row8_col4, #T_7475e_row8_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7475e_row4_col0 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_7475e_row4_col2 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_7475e_row4_col3 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_7475e_row4_col4 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_7475e_row4_col5 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_7475e_row5_col0 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_7475e_row5_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_7475e_row5_col2 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_7475e_row5_col3 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_7475e_row6_col0 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_7475e_row6_col1 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_7475e_row6_col2 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_7475e_row7_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_7475e_row7_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7475e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Count Number</th>
#       <th id="T_7475e_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_7475e_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_7475e_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_7475e_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_7475e_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_7475e_level0_col5" class="col_heading level0 col5" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Candidate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7475e_level0_row0" class="row_heading level0 row0" >*Shane Ross, NON-P.</th>
#       <td id="T_7475e_row0_col0" class="data row0 col0" >10202</td>
#       <td id="T_7475e_row0_col1" class="data row0 col1" >10411</td>
#       <td id="T_7475e_row0_col2" class="data row0 col2" >10411</td>
#       <td id="T_7475e_row0_col3" class="data row0 col3" >10411</td>
#       <td id="T_7475e_row0_col4" class="data row0 col4" >10411</td>
#       <td id="T_7475e_row0_col5" class="data row0 col5" >10411</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row1" class="row_heading level0 row1" >*Josepha Madigan, F.G.</th>
#       <td id="T_7475e_row1_col0" class="data row1 col0" >6668</td>
#       <td id="T_7475e_row1_col1" class="data row1 col1" >6835</td>
#       <td id="T_7475e_row1_col2" class="data row1 col2" >7180</td>
#       <td id="T_7475e_row1_col3" class="data row1 col3" >7290</td>
#       <td id="T_7475e_row1_col4" class="data row1 col4" >8579</td>
#       <td id="T_7475e_row1_col5" class="data row1 col5" >9488</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row2" class="row_heading level0 row2" >Alan Shatter, F.G.</th>
#       <td id="T_7475e_row2_col0" class="data row2 col0" >5905</td>
#       <td id="T_7475e_row2_col1" class="data row2 col1" >5979</td>
#       <td id="T_7475e_row2_col2" class="data row2 col2" >6195</td>
#       <td id="T_7475e_row2_col3" class="data row2 col3" >6268</td>
#       <td id="T_7475e_row2_col4" class="data row2 col4" >7745</td>
#       <td id="T_7475e_row2_col5" class="data row2 col5" >8444</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row3" class="row_heading level0 row3" >Mary White, F.F.</th>
#       <td id="T_7475e_row3_col0" class="data row3 col0" >4220</td>
#       <td id="T_7475e_row3_col1" class="data row3 col1" >4325</td>
#       <td id="T_7475e_row3_col2" class="data row3 col2" >4761</td>
#       <td id="T_7475e_row3_col3" class="data row3 col3" >5165</td>
#       <td id="T_7475e_row3_col4" class="data row3 col4" >5463</td>
#       <td id="T_7475e_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row4" class="row_heading level0 row4" >*Catherine Martin, G.P.</th>
#       <td id="T_7475e_row4_col0" class="data row4 col0" >4122</td>
#       <td id="T_7475e_row4_col1" class="data row4 col1" >4314</td>
#       <td id="T_7475e_row4_col2" class="data row4 col2" >4812</td>
#       <td id="T_7475e_row4_col3" class="data row4 col3" >6105</td>
#       <td id="T_7475e_row4_col4" class="data row4 col4" >7255</td>
#       <td id="T_7475e_row4_col5" class="data row4 col5" >9421</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row5" class="row_heading level0 row5" >Alex White, LAB.</th>
#       <td id="T_7475e_row5_col0" class="data row5 col0" >4048</td>
#       <td id="T_7475e_row5_col1" class="data row5 col1" >4080</td>
#       <td id="T_7475e_row5_col2" class="data row5 col2" >4258</td>
#       <td id="T_7475e_row5_col3" class="data row5 col3" >4436</td>
#       <td id="T_7475e_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_7475e_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row6" class="row_heading level0 row6" >Sorcha Nic Cormaic, S.F.</th>
#       <td id="T_7475e_row6_col0" class="data row6 col0" >2858</td>
#       <td id="T_7475e_row6_col1" class="data row6 col1" >2896</td>
#       <td id="T_7475e_row6_col2" class="data row6 col2" >3076</td>
#       <td id="T_7475e_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_7475e_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_7475e_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row7" class="row_heading level0 row7" >Peter Mathews, NON-P.</th>
#       <td id="T_7475e_row7_col0" class="data row7 col0" >2021</td>
#       <td id="T_7475e_row7_col1" class="data row7 col1" >2241</td>
#       <td id="T_7475e_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_7475e_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_7475e_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_7475e_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_7475e_level0_row8" class="row_heading level0 row8" >Alan Daveron, R.I.</th>
#       <td id="T_7475e_row8_col0" class="data row8 col0" >1055</td>
#       <td id="T_7475e_row8_col1" class="data row8 col1" >0</td>
#       <td i

# %%
charter(count_details)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Dublin Rathdown, 2020
#
# Four years later, the natural order was restored. The first three in the first count all sailed home on calm seas.

# %%
count_details = get_count_details(data[2020]['count'], 18)
count_details.style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_0e2f7_row0_col0, #T_0e2f7_row0_col1, #T_0e2f7_row0_col2, #T_0e2f7_row0_col3, #T_0e2f7_row0_col4, #T_0e2f7_row0_col5, #T_0e2f7_row0_col6, #T_0e2f7_row0_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_0e2f7_row1_col0 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_0e2f7_row1_col1 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_0e2f7_row1_col2 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_0e2f7_row1_col3 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_0e2f7_row1_col4 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_0e2f7_row1_col5, #T_0e2f7_row2_col6 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_0e2f7_row1_col6 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_0e2f7_row1_col7 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_0e2f7_row2_col0, #T_0e2f7_row2_col1 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_0e2f7_row2_col2 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_0e2f7_row2_col3, #T_0e2f7_row4_col6 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_0e2f7_row2_col4 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_0e2f7_row2_col5 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_0e2f7_row2_col7 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_0e2f7_row3_col0 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_0e2f7_row3_col1 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_0e2f7_row3_col2 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_0e2f7_row3_col3 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_0e2f7_row3_col4 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_0e2f7_row3_col5 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_0e2f7_row3_col6 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_0e2f7_row3_col7, #T_0e2f7_row5_col5, #T_0e2f7_row5_col6, #T_0e2f7_row5_col7, #T_0e2f7_row6_col4, #T_0e2f7_row6_col5, #T_0e2f7_row6_col6, #T_0e2f7_row6_col7, #T_0e2f7_row7_col3, #T_0e2f7_row7_col4, #T_0e2f7_row7_col5, #T_0e2f7_row7_col6, #T_0e2f7_row7_col7, #T_0e2f7_row8_col2, #T_0e2f7_row8_col3, #T_0e2f7_row8_col4, #T_0e2f7_row8_col5, #T_0e2f7_row8_col6, #T_0e2f7_row8_col7, #T_0e2f7_row9_col1, #T_0e2f7_row9_col2, #T_0e2f7_row9_col3, #T_0e2f7_row9_col4, #T_0e2f7_row9_col5, #T_0e2f7_row9_col6, #T_0e2f7_row9_col7, #T_0e2f7_row10_col0, #T_0e2f7_row10_col1, #T_0e2f7_row10_col2, #T_0e2f7_row10_col3, #T_0e2f7_row10_col4, #T_0e2f7_row10_col5, #T_0e2f7_row10_col6, #T_0e2f7_row10_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_0e2f7_row4_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_0e2f7_row4_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_0e2f7_row4_col2 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_0e2f7_row4_col3 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_0e2f7_row4_col4 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_0e2f7_row4_col5 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_0e2f7_row4_col7 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_0e2f7_row5_col0 {
#   background-color: #feca79;
#   color: #000000;
# }
# #T_0e2f7_row5_col1 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_0e2f7_row5_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_0e2f7_row5_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_0e2f7_row5_col4 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_0e2f7_row6_col0 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_0e2f7_row6_col1, #T_0e2f7_row6_col2, #T_0e2f7_row6_col3 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_0e2f7_row7_col0 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_0e2f7_row7_col1 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_0e2f7_row7_col2 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_0e2f7_row8_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_0e2f7_row8_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_0e2f7_row9_col0 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0e2f7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Count Number</th>
#       <th id="T_0e2f7_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_0e2f7_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_0e2f7_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_0e2f7_level0_col3" class="col_heading level0 col3" >4</th>
#       <th id="T_0e2f7_level0_col4" class="col_heading level0 col4" >5</th>
#       <th id="T_0e2f7_level0_col5" class="col_heading level0 col5" >6</th>
#       <th id="T_0e2f7_level0_col6" class="col_heading level0 col6" >7</th>
#       <th id="T_0e2f7_level0_col7" class="col_heading level0 col7" >8</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Candidate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e2f7_level0_row0" class="row_heading level0 row0" >*Catherine Martin, G.P.</th>
#       <td id="T_0e2f7_row0_col0" class="data row0 col0" >8958</td>
#       <td id="T_0e2f7_row0_col1" class="data row0 col1" >9171</td>
#       <td id="T_0e2f7_row0_col2" class="data row0 col2" >9431</td>
#       <td id="T_0e2f7_row0_col3" class="data row0 col3" >9949</td>
#       <td id="T_0e2f7_row0_col4" class="data row0 col4" >11444</td>
#       <td id="T_0e2f7_row0_col5" class="data row0 col5" >11444</td>
#       <td id="T_0e2f7_row0_col6" class="data row0 col6" >10601</td>
#       <td id="T_0e2f7_row0_col7" class="data row0 col7" >10601</td>
#     </tr>
#     <tr>
#       <th id="T_0e2f7_level0_row1" class="row_heading level0 row1" >*Neale Richmond, F.G.</th>
#       <td id="T_0e2f7_row1_col0" class="data row1 col0" >6743</td>
#       <td id="T_0e2f7_row1_col1" class="data row1 col1" >6789</td>
#       <td id="T_0e2f7_row1_col2" class="data row1 col2" >6887</td>
#       <td id="T_0e2f7_row1_col3" class="data row1 col3" >6926</td>
#       <td id="T_0e2f7_row1_col4" class="data row1 col4" >7461</td>
#       <td id="T_0e2f7_row1_col5" class="data row1 col5" >8675</td>
#       <td id="T_0e2f7_row1_col6" class="data row1 col6" >8950</td>
#       <td id="T_0e2f7_row1_col7" class="data row1 col7" >9704</td>
#     </tr>
#     <tr>
#       <th id="T_0e2f7_level0_row2" class="row_heading level0 row2" >*Josepha Madigan, F.G.</th>
#       <td id="T_0e2f7_row2_col0" class="data row2 col0" >6482</td>
#       <td id="T_0e2f7_row2_col1" class="data row2 col1" >6555</td>
#       <td id="T_0e2f7_row2_col2" class="data row2 col2" >6603</td>
#       <td id="T_0e2f7_row2_col3" class="data row2 col3" >6624</td>
#       <td id="T_0e2f7_row2_col4" class="data row2 col4" >6964</td>
#       <td id="T_0e2f7_row2_col5" class="data row2 col5" >7835</td>
#       <td id="T_0e2f7_row2_col6" class="data row2 col6" >8065</td>
#       <td id="T_0e2f7_row2_col7" class="data row2 col7" >8677</td>
#     </tr>
#     <tr>
#       <th id="T_0e2f7_level0_row3" class="row_heading level0 row3" >Sorcha Nic Cormaic Nic Cormaic, S.F.</th>
#       <td id="T_0e2f7_row3_col0" class="data row3 col0" >4926</td>
#       <td id="T_0e2f7_row3_col1" class="data row3 col1" >4980</td>
#       <td id="T_0e2f7_row3_col2" class="data row3 col2" >5082</td>
#       <td id="T_0e2f7_row3_col3" class="data row3 col3" >5716</td>
#       <td id="T_0e2f7_row3_col4" class="data row3 col4" >5991</td>
#       <td id="T_0e2f7_row3_col5" class="data row3 col5" >6538</td>
#       <td id="T_0e2f7_row3_col6" class="data row3 col6" >6726</td>
#       <td id="T_0e2f7_row3_col7" class="data row3 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0e2f7_level0_row4" class="row_heading level0 row4" >Shay Brennan, F.F.</th>
#       <td id="T_0e2f7_row4_col0" class="data row4 col0" >4549</td>
#       <td id="T_0e2f7_row4_col1" class="data row4 col1" >5118</td>
#       <td id="T_0e2f7_row4_col2" class="data row4 col2" >5532<

# %%
charter(count_details)
# Out:
# alt.LayerChart(...)
